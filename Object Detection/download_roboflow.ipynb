# %%
from roboflow import Roboflow
rf = Roboflow(api_key="aKhWhzfU0gyUOT2JCA3F")
project = rf.workspace("saran-ditjarern-kuynl").project("durian-sw6us")
version = project.version(9)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to durian-9 in yolov8:: 100%|██████████| 233/233 [00:00<00:00, 3212.90it/s]
